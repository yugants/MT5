# %%
import talib
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import datetime
import MetaTrader5 as mt5
import pandas_ta as ta
from scipy.signal import savgol_filter, find_peaks
pd.set_option('mode.chained_assignment', None)

# %%
if not mt5.initialize(login=114781990, server="Exness-MT5Trial6",password="Mypassword$1234"):
            print("initialize() failed, error code =",mt5.last_error())
            quit()
        
login = 114781990
password = 'Mypassword$1234'
server = 'Exness-MT5Trial6'

mt5.login(login, password, server)

rate = mt5.copy_rates_from('EURUSDm', mt5.TIMEFRAME_M15, datetime.datetime.now(), 3000)

nf = pd.DataFrame(rate)
#         print('getting data')

nf['date']=pd.to_datetime(nf['time'], unit='s')

nf.set_index(np.arange(len(nf)), inplace = True)
nf = nf.drop(['spread', 'real_volume', 'tick_volume', 'time'], axis='columns')


# nf.to_excel('EURUSD.xlsx')

df = nf.iloc[:500]  # First half
df2 = nf.iloc[500:]  # Second half


# print(df.atr.iloc[-1])

df['trend'] = 'no trend'

# %%
def find_trend():
    
    global df
    
#     print(df.head())

    df['atr'] = ta.atr(high=df.high, low=df.low, close=df.close)

    df.dropna(inplace = True)
    
    
    if len(df) - 1 > 30:  # Ensure window_length is within bounds
        
    
        df['close_smooth'] = savgol_filter(df.close, 30, 10)

    #     df['close_smooth'] = savgol_filter(df.close, 30, 10)

        atr = df.atr.iloc[-1]

    #     print('atr: ', atr)

    #     List which contains all peaks index value
        peaks_idx,_ = find_peaks(df.close_smooth, distance = 15, width = 2, prominence= atr)

    #     List which contains all troughs index value
        troughs_idx,_ = find_peaks(-1*df.close_smooth, distance = 15, width = 2, prominence= atr)

        print('peaks_idx: ', len(peaks_idx))
        print('troughs_idx: ', troughs_idx[-2])

        if len(peaks_idx) > 1 and len(troughs_idx) > 1:

            current_high = df.close_smooth.iloc[peaks_idx[-1]]

            prev_high = df.close_smooth.iloc[peaks_idx[-2]]

            current_low = df.close_smooth.iloc[troughs_idx[-1]]

            prev_low = df.close_smooth.iloc[troughs_idx[-2]]
            
            print('C_high: ', current_high)
            print('C_low: ', current_low)
            print('Prev_H: ', prev_high)
            print('Prev_L: ', prev_low)

            if current_high > prev_high and current_low > prev_low:
                
                print('up')

                return 'up'

            elif current_high < prev_high and current_low < prev_low:
                
                print('down')

                return 'down'

    else:
        
        print('no trend')

        return 'no trend'

# %%
#  Caller
past_df = pd.DataFrame()
def Caller():
    
    global df, df2, past_df
    # Initialize an empty DataFrame to store the past data that gets dropped
    

#         Loop for taking the live data
    for index, row in df2.iterrows():
        # Add live data to the df DataFrame
        df = df.append(row, ignore_index=True)
#             self.df = pd.concat([self.df, row], ignore_index=True)

        # Delete the first row if the DataFrame has more than 202 rows
        if len(df) > 500:
            # Save the dropped row in past_df
            past_df = past_df.append(df.iloc[0], ignore_index=True)
            df = df.iloc[1:].reset_index(drop=True)
        
        
        df.loc[len(df)-1, 'trend'] = find_trend()
        

    result_df = pd.concat([past_df, df], ignore_index=True)

    result_df.to_excel('combined.xlsx')

# %%
Caller()
# Out:
# peaks_idx:  8
# troughs_idx:  408
# C_high:  1.0913413377479693
# C_low:  1.090462406625706
# Prev_H:  1.092980080561425
# Prev_L:  1.090128078609347
# peaks_idx:  7
# troughs_idx:  352
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  7
# troughs_idx:  338
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  7
# troughs_idx:  324
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  7
# troughs_idx:  310
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  7
# troughs_idx:  296
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  6
# troughs_idx:  282
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  6
# troughs_idx:  268
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  6
# troughs_idx:  254
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  6
# troughs_idx:  240
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  6
# troughs_idx:  226
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  5
# troughs_idx:  212
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  5
# troughs_idx:  198
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  5
# troughs_idx:  184
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  4
# troughs_idx:  170
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  4
# troughs_idx:  156
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  4
# troughs_idx:  142
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  4
# troughs_idx:  128
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  4
# troughs_idx:  114
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  3
# troughs_idx:  100
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  3
# troughs_idx:  86
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  2
# troughs_idx:  72
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  2
# troughs_idx:  58
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  2
# troughs_idx:  44
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  2
# troughs_idx:  30
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938208717336744
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  2
# troughs_idx:  16
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0938458884864277
# Prev_L:  1.0924454609023393
# down
# peaks_idx:  2
# troughs_idx:  3
# C_high:  1.092980080561425
# C_low:  1.090128078609347
# Prev_H:  1.0939569937913092
# Prev_L:  1.0919247919321289
# down
# peaks_idx:  1
# C:\Users\hp\AppData\Local\Temp\ipykernel_1440\3972348397.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_1440\3972348397.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_df = past_df.append(df.iloc[0], ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_1440\3972348397.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [114], line 1
# ----> 1 Caller()
#
# Cell In [113], line 22, in Caller()
#      18         past_df = past_df.append(df.iloc[0], ignore_index=True)
#      19         df = df.iloc[1:].reset_index(drop=True)
# ---> 22     df.loc[len(df)-1, 'trend'] = find_trend()
#      25 result_df = pd.concat([past_df, df], ignore_index=True)
#      27 result_df.to_excel('combined.xlsx')
#
# Cell In [112], line 30, in find_trend()
#      27 troughs_idx,_ = find_peaks(-1*df.close_smooth, distance = 15, width = 2, prominence= atr)
#      29 print('peaks_idx: ', len(peaks_idx))
# ---> 30 print('troughs_idx: ', troughs_idx[-2])
#      32 if len(peaks_idx) > 1 and len(troughs_idx) > 1:
#      34     current_high = df.close_smooth.iloc[peaks_idx[-1]]
#
# IndexError: index -2 is out of bounds for axis 0 with size 1
