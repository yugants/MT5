# %%
import talib
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import datetime
import MetaTrader5 as mt5

# %%
if not mt5.initialize(login=114781990, server="Exness-MT5Trial6",password="Mypassword$1234"):
            print("initialize() failed, error code =",mt5.last_error())
            quit()
        
login = 114781990
password = 'Mypassword$1234'
server = 'Exness-MT5Trial6'

mt5.login(login, password, server)

rate = mt5.copy_rates_from('EURUSDm', mt5.TIMEFRAME_M15, datetime.datetime.now(), 5000)

nf = pd.DataFrame(rate)
#         print('getting data')

nf['date']=pd.to_datetime(nf['time'], unit='s')

nf.set_index(np.arange(len(nf)), inplace = True)
nf = nf.drop(['spread', 'real_volume', 'tick_volume', 'time'], axis='columns')


# nf.to_excel('EURUSD.xlsx')

df = nf.iloc[:500]  # First half
df2 = nf.iloc[500:]  # Second half

# %%
def get_kc( high, low, close, kc_lookback, multiplier, atr_lookback):
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift()))
    tr3 = pd.DataFrame(abs(low - close.shift()))

    # Calculate True Range as the element-wise maximum of the three components
    tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
    atr = tr.ewm(alpha=1/atr_lookback).mean()

    kc_middle = close.ewm(span=kc_lookback).mean()
    kc_upper = kc_middle + multiplier * atr
    kc_lower = kc_middle - multiplier * atr

    return kc_middle.iloc[-1], kc_upper.iloc[-1], kc_lower.iloc[-1]

def candle(df):
    '''Return candle colour'''

    if df['close'] - df['open'] > 0:
        return 'G'

    else:
        return 'R'
    
    
def calculate_indicators():

#         print('calc_indicator')
    global df
    length = len(df) - 1

    df.loc[length, 'EMA_8'] = talib.EMA(df['close'], timeperiod=8).iloc[-1]
    df.loc[length, 'EMA_50'] = talib.EMA(df['close'], timeperiod=50).iloc[-1]
    df.loc[length, 'EMA_200'] = talib.EMA(df['close'], timeperiod=200).iloc[-1]
    df.loc[length, 'RSI'] = talib.RSI(df['close'], timeperiod=21).iloc[-1]

    df.loc[length, 'candle'] = candle(df.iloc[-1])

    df.loc[length, 'EMA_20'], df.loc[length, 'upper_keltner'], df.loc[length, 'lower_keltner'] = get_kc(df['high'], df['low'], df['close'], kc_lookback=20, multiplier=2.25, atr_lookback=10)



def check_body( df):
    #     Calculate 0.7 % of entry price
#     fOR 1H FOREX
        one_percent = df['open']/100 
        percent = one_percent * 0.06
        hammer_per = one_percent * 0.06
        
        max_candle_size = 0.11


    #     Calculate candle size close-open
        if df['candle'] == 'G':
            candle_size = df['close'] - df['open']
            upper_wick = df['high'] - df['close']
            lower_wick = df['open'] - df['low']

        else:
            candle_size = abs(df['close'] - df['open'])
            upper_wick = df['high'] - df['open']
            lower_wick = df['close'] - df['low']

        upper_wick_per = (upper_wick/one_percent) 
        lower_wick_per = (lower_wick/one_percent) 



    #     check for entry candle size and Max candle size 0.11 %
        if ((candle_size >= percent) and candle_size <= (max_candle_size * one_percent) and
         (candle_size > upper_wick) and (candle_size > lower_wick) and
        (upper_wick_per < 0.06) and (lower_wick_per < 0.06)):

            if df['candle'] == 'G' and df['high'] < df['upper_keltner'] :

                return 1

            elif df['candle'] == 'R' and df['low'] > df['lower_keltner'] :

                return 1

            else:

                return 0

    #     condition for hammmer
    #     lower wick is atleast 50 % of total size 
    #     Green Hammer 
    # need to add max wick of opposite dir
        elif ( (df['candle'] == 'G') and (df['open'] - df['low']) >= ((df['high'] - df['low']) * 0.5) and
              (candle_size >= hammer_per) and (candle_size > upper_wick)and
              candle_size <= (max_candle_size * one_percent) and ((upper_wick_per < 0.06))  
             and df['high'] < df['upper_keltner']):

            return 1


#     For Red Hammer
# need to add max wick of opposite dir
        elif ( (df['candle'] == 'R') and (df['high'] - df['open']) >= (abs(df['high'] - df['low']) * 0.5) and 
              (candle_size >= hammer_per) and (candle_size > lower_wick)and candle_size <= (max_candle_size * one_percent) and 
              ((lower_wick_per < 0.06)) and df['low'] > df['lower_keltner'] ):

            return 1


        else:
            return 0

# %%
def check_inside_kt( x):

    if  ( x['high'] < x['upper_keltner'] and x['low'] > x['lower_keltner']):
        return 1

    else:
        return 0

# %%
def check_last(entry_candle, entry_index, entry_candle_size):
    
    global df

    prev_index = entry_index - 1 
    
    prev_candle = df.iloc[prev_index]
    
    prev_candle_size = abs(prev_candle['open'] - prev_candle['close'])

    if entry_candle['candle'] == 'G':

#       If last candle Red then entry candle must close above last candle open
        if (prev_candle['candle'] == 'R' and entry_candle['close'] >= prev_candle[ 'open'] and
           prev_candle_size >= 0.5 * entry_candle_size):
            
            return True

        else:
            return False

    elif entry_candle['candle'] == 'R':

#       If last candle Red then entry candle must close below last candle open
        if (prev_candle['candle'] == 'G' and entry_candle['close'] <= prev_candle[ 'open'] and
           prev_candle_size >= 0.5 * entry_candle_size):
            
            return True

        else:
            return False


def check_prev_candle(entry_candle):
    
    global df
    

    entry_index = df[df['date'] == entry_candle['date']].index[0]
    entry_candle_size = abs(entry_candle['open'] - entry_candle['close'])
    
    
#     For 2 candle entry
    if check_last(entry_candle, entry_index, entry_candle_size) == True:
        
        return True
    
    else:

        if entry_candle['candle'] == 'G':
            for i in range(entry_index - 1, max(-1, entry_index - 11), -1):
                current_candle = df.iloc[i]
                current_candle_size = abs(current_candle['open'] - current_candle['close'])

                if (current_candle['candle'] == 'R' and
                    current_candle['open'] <= entry_candle['close'] and
                    current_candle_size >= 0.5 * entry_candle_size and 
                    current_candle_size <= 1.2 * entry_candle_size):

                    for j in range(i + 1, entry_index):
                        intermediate_candle = df.iloc[j]

                        if (abs(intermediate_candle['open'] - intermediate_candle['close']) <= 0.6 *
                            current_candle_size and j < entry_index - 1):
                            continue
                        elif j == entry_index - 1:
                            return True
                        else:
                            return False
                    break

        elif entry_candle['candle'] == 'R':
    #         print('Testing R candle')
            for i in range(entry_index - 1, max(-1, entry_index - 11), -1):
                current_candle = df.iloc[i]
                current_candle_size = abs(current_candle['open'] - current_candle['close'])

                if (current_candle['candle'] == 'G' and
                    current_candle['open'] >= entry_candle['close'] and
                    current_candle_size >= 0.5 * entry_candle_size and 
                    current_candle_size <= 1.2 * entry_candle_size):
    #                 print('R in IF')
                    for j in range(i + 1, entry_index):
                        intermediate_candle = df.iloc[j]

                        if (abs(intermediate_candle['open'] - intermediate_candle['close']) <= 0.6 *
                            current_candle_size and j < entry_index - 1):
                            continue

                        elif j == entry_index - 1:
                            return True

                        else:
                            return False

                    break

    return False

# %%
# Condition Check

checker = pd.DataFrame()

def check_conditions():

    global df, checker
    length = len(df) - 1

#         Checking all entry conditions

    df.loc[length, 'candle'] = candle(df.iloc[-1])
    
    df.loc[length, 'pos'] = check_inside_kt(df.iloc[-1])

    df.loc[length, 'candle_size'] = check_body(df.iloc[-1])
    
#     print('Candle: ',df.loc[length, 'candle'] )
#     print('KT: ', df.loc[length, 'pos'])
#     print('Size: ', df.loc[length, 'candle_size'])

    df.loc[length, 'prev_candle'] = check_prev_candle(df.iloc[-1])
    
#     print('Prev candle: ', df.loc[length, 'prev_candle'])
    
    if (df.loc[length, 'pos'] == 1 and 
        df.loc[length, 'candle_size'] == 1 and df.loc[length, 'prev_candle'] == True):
    
#         print('Complete')
        print('DF: ', df.iloc[-1])

# %%
#  Caller
past_df = pd.DataFrame()
def Caller():
    
    global df, df2, past_df
    # Initialize an empty DataFrame to store the past data that gets dropped
    

#         Loop for taking the live data
    for index, row in df2.iterrows():
        # Add live data to the df DataFrame
        df = df.append(row, ignore_index=True)
#             self.df = pd.concat([self.df, row], ignore_index=True)

        # Delete the first row if the DataFrame has more than 202 rows
        if len(df) > 500:
            # Save the dropped row in past_df
            past_df = past_df.append(df.iloc[0], ignore_index=True)
            df = df.iloc[1:].reset_index(drop=True)
            
            
        calculate_indicators()

        check_conditions()

    result_df = pd.concat([past_df, df], ignore_index=True)

    result_df.to_excel('combined.xlsx')

# %%
Caller()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13240\4103600624.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_13240\4103600624.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_df = past_df.append(df.iloc[0], ignore_index=True)
# DF:  open                         1.12393
# high                          1.1249
# low                           1.1239
# close                        1.12484
# date             2023-07-18 09:45:00
# EMA_8                       1.124518
# EMA_50                      1.124481
# EMA_200                     1.115786
# RSI                        50.876845
# candle                             G
# EMA_20                      1.124821
# upper_keltner               1.126972
# lower_keltner               1.122669
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.12568
# high                         1.12574
# low                          1.12464
# close                        1.12485
# date             2023-07-18 11:00:00
# EMA_8                       1.125018
# EMA_50                      1.124612
# EMA_200                     1.116244
# RSI                        50.289078
# candle                             R
# EMA_20                      1.124973
# upper_keltner               1.126955
# lower_keltner               1.122991
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.12425
# high                          1.1255
# low                          1.12419
# close                        1.12529
# date             2023-07-18 11:45:00
# EMA_8                       1.124958
# EMA_50                      1.124643
# EMA_200                     1.116498
# RSI                        52.620613
# candle                             G
# EMA_20                      1.124951
# upper_keltner               1.127036
# lower_keltner               1.122867
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.12216
# high                         1.12287
# low                          1.12216
# close                        1.12287
# date             2023-07-19 01:30:00
# EMA_8                       1.122766
# EMA_50                      1.122966
# EMA_200                     1.119163
# RSI                        49.762953
# candle                             G
# EMA_20                      1.122784
# upper_keltner               1.123762
# lower_keltner               1.121806
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.12292
# high                         1.12292
# low                          1.12198
# close                        1.12198
# date             2023-07-19 10:00:00
# EMA_8                        1.12282
# EMA_50                      1.122646
# EMA_200                     1.120127
# RSI                        46.545007
# candle                             R
# EMA_20                      1.122672
# upper_keltner               1.124593
# lower_keltner               1.120752
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.11219
# high                         1.11319
# low                          1.11213
# close                        1.11315
# date             2023-07-24 05:45:00
# EMA_8                        1.11243
# EMA_50                      1.112529
# EMA_200                     1.114453
# RSI                         55.73213
# candle                             G
# EMA_20                      1.112451
# upper_keltner               1.113485
# lower_keltner               1.111416
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10813
# high                         1.10896
# low                          1.10802
# close                        1.10892
# date             2023-07-24 10:30:00
# EMA_8                       1.108522
# EMA_50                      1.110824
# EMA_200                     1.113666
# RSI                        42.261037
# candle                             G
# EMA_20                      1.109442
# upper_keltner               1.111703
# lower_keltner               1.107182
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.1107
# high                          1.1107
# low                          1.10966
# close                         1.1097
# date             2023-07-24 11:45:00
# EMA_8                       1.109537
# EMA_50                      1.110651
# EMA_200                     1.113482
# RSI                        46.747217
# candle                             R
# EMA_20                       1.10962
# upper_keltner               1.111795
# lower_keltner               1.107444
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10783
# high                         1.10815
# low                          1.10694
# close                        1.10706
# date             2023-07-25 07:45:00
# EMA_8                       1.107708
# EMA_50                      1.107511
# EMA_200                     1.110094
# RSI                        45.733685
# candle                             R
# EMA_20                      1.107617
# upper_keltner               1.109062
# lower_keltner               1.106173
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10761
# high                         1.10762
# low                          1.10683
# close                        1.10691
# date             2023-07-26 09:30:00
# EMA_8                       1.107071
# EMA_50                      1.105781
# EMA_200                     1.106966
# RSI                         59.37792
# candle                             R
# EMA_20                      1.106516
# upper_keltner               1.107937
# lower_keltner               1.105096
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.11071
# high                         1.11083
# low                          1.10989
# close                        1.10989
# date             2023-07-27 02:45:00
# EMA_8                       1.109955
# EMA_50                      1.108438
# EMA_200                     1.107532
# RSI                         57.24583
# candle                             R
# EMA_20                      1.109287
# upper_keltner               1.110867
# lower_keltner               1.107706
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10964
# high                         1.10992
# low                          1.10877
# close                        1.10884
# date             2023-07-27 05:45:00
# EMA_8                       1.109575
# EMA_50                      1.108979
# EMA_200                     1.107793
# RSI                        47.876973
# candle                             R
# EMA_20                      1.109622
# upper_keltner               1.111069
# lower_keltner               1.108175
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09983
# high                         1.09984
# low                          1.09881
# close                        1.09881
# date             2023-07-27 18:00:00
# EMA_8                       1.099463
# EMA_50                      1.104636
# EMA_200                     1.107119
# RSI                        31.734397
# candle                             R
# EMA_20                      1.101045
# upper_keltner                1.10366
# lower_keltner                1.09843
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09778
# high                         1.09847
# low                          1.09772
# close                        1.09844
# date             2023-07-28 02:15:00
# EMA_8                       1.098066
# EMA_50                      1.099619
# EMA_200                     1.104495
# RSI                        46.101681
# candle                             G
# EMA_20                      1.098038
# upper_keltner               1.099232
# lower_keltner               1.096844
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09762
# high                         1.09781
# low                          1.09659
# close                        1.09665
# date             2023-07-28 04:00:00
# EMA_8                       1.097736
# EMA_50                      1.099192
# EMA_200                     1.104053
# RSI                        36.298982
# candle                             R
# EMA_20                      1.097926
# upper_keltner               1.099589
# lower_keltner               1.096262
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09537
# high                         1.09682
# low                          1.09532
# close                        1.09638
# date             2023-07-28 08:30:00
# EMA_8                       1.096068
# EMA_50                      1.097867
# EMA_200                     1.102841
# RSI                         44.55122
# candle                             G
# EMA_20                      1.096679
# upper_keltner               1.099563
# lower_keltner               1.093794
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10295
# high                         1.10395
# low                          1.10295
# close                        1.10378
# date             2023-07-28 15:45:00
# EMA_8                       1.102985
# EMA_50                       1.10015
# EMA_200                       1.1023
# RSI                        65.729572
# candle                             G
# EMA_20                       1.10173
# upper_keltner               1.104294
# lower_keltner               1.099166
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10277
# high                         1.10282
# low                          1.10177
# close                        1.10188
# date             2023-07-28 17:15:00
# EMA_8                       1.102684
# EMA_50                      1.100709
# EMA_200                     1.102333
# RSI                        54.358158
# candle                             R
# EMA_20                      1.102178
# upper_keltner               1.104263
# lower_keltner               1.100092
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10384
# high                         1.10444
# low                          1.10299
# close                        1.10314
# date             2023-07-31 14:30:00
# EMA_8                       1.103339
# EMA_50                       1.10252
# EMA_200                     1.102237
# RSI                         52.99484
# candle                             R
# EMA_20                      1.103035
# upper_keltner               1.105087
# lower_keltner               1.100983
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09789
# high                         1.09789
# low                          1.09705
# close                        1.09712
# date             2023-08-01 08:30:00
# EMA_8                       1.097995
# EMA_50                      1.099044
# EMA_200                     1.100681
# RSI                        38.142459
# candle                             R
# EMA_20                      1.098415
# upper_keltner               1.100285
# lower_keltner               1.096545
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0978
# high                         1.09844
# low                          1.09686
# close                        1.09691
# date             2023-08-01 15:00:00
# EMA_8                       1.097057
# EMA_50                      1.097761
# EMA_200                     1.099825
# RSI                        46.376274
# candle                             R
# EMA_20                      1.097128
# upper_keltner               1.099616
# lower_keltner               1.094641
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09692
# high                         1.09697
# low                          1.09615
# close                        1.09619
# date             2023-08-01 15:15:00
# EMA_8                       1.096865
# EMA_50                        1.0977
# EMA_200                     1.099789
# RSI                        42.935411
# candle                             R
# EMA_20                      1.097039
# upper_keltner               1.099462
# lower_keltner               1.094616
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09616
# high                          1.0971
# low                          1.09603
# close                        1.09698
# date             2023-08-01 15:45:00
# EMA_8                        1.09677
# EMA_50                      1.097614
# EMA_200                     1.099727
# RSI                        47.649789
# candle                             G
# EMA_20                      1.096958
# upper_keltner               1.099302
# lower_keltner               1.094615
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10073
# high                         1.10075
# low                          1.09948
# close                        1.09975
# date             2023-08-02 00:00:00
# EMA_8                       1.100384
# EMA_50                      1.098651
# EMA_200                     1.099494
# RSI                          55.3468
# candle                             R
# EMA_20                      1.099596
# upper_keltner               1.101269
# lower_keltner               1.097923
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10038
# high                         1.10052
# low                          1.09909
# close                        1.09912
# date             2023-08-02 01:45:00
# EMA_8                       1.099755
# EMA_50                      1.098886
# EMA_200                     1.099518
# RSI                        50.504599
# candle                             R
# EMA_20                      1.099608
# upper_keltner               1.101273
# lower_keltner               1.097943
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0994
# high                         1.09952
# low                          1.09829
# close                         1.0983
# date             2023-08-02 06:00:00
# EMA_8                       1.098977
# EMA_50                      1.098848
# EMA_200                     1.099436
# RSI                         45.80374
# candle                             R
# EMA_20                      1.099005
# upper_keltner               1.100407
# lower_keltner               1.097602
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09271
# high                         1.09403
# low                          1.09265
# close                        1.09392
# date             2023-08-03 05:45:00
# EMA_8                       1.093048
# EMA_50                      1.093942
# EMA_200                     1.096493
# RSI                        51.531154
# candle                             G
# EMA_20                      1.093312
# upper_keltner               1.094541
# lower_keltner               1.092083
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09244
# high                          1.0938
# low                          1.09233
# close                        1.09345
# date             2023-08-03 09:00:00
# EMA_8                       1.092435
# EMA_50                      1.093325
# EMA_200                      1.09598
# RSI                        52.351025
# candle                             G
# EMA_20                      1.092638
# upper_keltner                1.09451
# lower_keltner               1.090765
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09313
# high                         1.09328
# low                          1.09218
# close                        1.09228
# date             2023-08-03 10:00:00
# EMA_8                       1.092573
# EMA_50                       1.09323
# EMA_200                     1.095843
# RSI                        45.105625
# candle                             R
# EMA_20                      1.092649
# upper_keltner               1.094558
# lower_keltner               1.090741
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09316
# high                         1.09441
# low                          1.09295
# close                        1.09438
# date             2023-08-03 15:00:00
# EMA_8                       1.093436
# EMA_50                      1.093245
# EMA_200                     1.095317
# RSI                        54.567753
# candle                             G
# EMA_20                      1.093206
# upper_keltner               1.096377
# lower_keltner               1.090035
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09373
# high                         1.09472
# low                          1.09346
# close                        1.09447
# date             2023-08-04 12:00:00
# EMA_8                       1.094217
# EMA_50                      1.094626
# EMA_200                     1.095074
# RSI                        48.649932
# candle                             G
# EMA_20                      1.094392
# upper_keltner               1.095865
# lower_keltner                1.09292
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10095
# high                         1.10097
# low                          1.10008
# close                        1.10024
# date             2023-08-07 01:00:00
# EMA_8                       1.100582
# EMA_50                      1.100277
# EMA_200                     1.097627
# RSI                        47.661762
# candle                             R
# EMA_20                      1.100696
# upper_keltner                1.10173
# lower_keltner               1.099661
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0947
# high                         1.09486
# low                          1.09376
# close                        1.09396
# date             2023-08-08 13:30:00
# EMA_8                       1.094561
# EMA_50                      1.096983
# EMA_200                      1.09817
# RSI                         32.01643
# candle                             R
# EMA_20                      1.095468
# upper_keltner               1.097479
# lower_keltner               1.093457
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09728
# high                         1.09819
# low                          1.09704
# close                        1.09804
# date             2023-08-09 07:30:00
# EMA_8                        1.09752
# EMA_50                      1.096626
# EMA_200                     1.097093
# RSI                        61.112887
# candle                             G
# EMA_20                      1.097155
# upper_keltner               1.098531
# lower_keltner               1.095778
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09894
# high                         1.09913
# low                          1.09768
# close                        1.09771
# date             2023-08-09 17:15:00
# EMA_8                       1.097997
# EMA_50                      1.097644
# EMA_200                      1.09731
# RSI                         49.79253
# candle                             R
# EMA_20                      1.097938
# upper_keltner               1.099799
# lower_keltner               1.096077
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10154
# high                         1.10295
# low                          1.10113
# close                        1.10275
# date             2023-08-10 13:30:00
# EMA_8                       1.102425
# EMA_50                      1.100753
# EMA_200                     1.098583
# RSI                        57.368999
# candle                             G
# EMA_20                      1.102053
# upper_keltner               1.105627
# lower_keltner               1.098478
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10277
# high                         1.10399
# low                          1.10247
# close                         1.1039
# date             2023-08-10 13:45:00
# EMA_8                       1.102753
# EMA_50                      1.100877
# EMA_200                     1.098637
# RSI                        61.327281
# candle                             G
# EMA_20                      1.102229
# upper_keltner               1.105788
# lower_keltner                1.09867
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.10392
# high                         1.10434
# low                          1.10231
# close                        1.10271
# date             2023-08-10 14:00:00
# EMA_8                       1.102743
# EMA_50                      1.100948
# EMA_200                     1.098678
# RSI                        55.707336
# candle                             R
# EMA_20                      1.102274
# upper_keltner               1.105934
# lower_keltner               1.098615
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09899
# high                         1.09904
# low                          1.09824
# close                        1.09833
# date             2023-08-10 18:30:00
# EMA_8                       1.099192
# EMA_50                      1.100636
# EMA_200                     1.098997
# RSI                        39.770899
# candle                             R
# EMA_20                       1.10031
# upper_keltner               1.102749
# lower_keltner               1.097872
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09831
# high                         1.09916
# low                          1.09817
# close                        1.09904
# date             2023-08-10 18:45:00
# EMA_8                       1.099158
# EMA_50                      1.100573
# EMA_200                     1.098998
# RSI                        43.247806
# candle                             G
# EMA_20                      1.100189
# upper_keltner               1.102607
# lower_keltner               1.097772
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09961
# high                         1.09964
# low                          1.09848
# close                        1.09858
# date             2023-08-11 09:15:00
# EMA_8                       1.099408
# EMA_50                      1.099176
# EMA_200                     1.098937
# RSI                        45.054746
# candle                             R
# EMA_20                      1.099296
# upper_keltner               1.100734
# lower_keltner               1.097858
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09632
# high                         1.09806
# low                          1.09613
# close                         1.0976
# date             2023-08-11 14:15:00
# EMA_8                       1.097195
# EMA_50                      1.098571
# EMA_200                     1.098836
# RSI                        45.232948
# candle                             G
# EMA_20                      1.097974
# upper_keltner               1.100739
# lower_keltner                1.09521
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09718
# high                         1.09752
# low                           1.0961
# close                        1.09611
# date             2023-08-11 15:00:00
# EMA_8                       1.097047
# EMA_50                      1.098398
# EMA_200                     1.098791
# RSI                        38.961258
# candle                             R
# EMA_20                      1.097723
# upper_keltner               1.100611
# lower_keltner               1.094836
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09558
# high                         1.09627
# low                          1.09558
# close                        1.09624
# date             2023-08-11 16:00:00
# EMA_8                       1.096246
# EMA_50                      1.098005
# EMA_200                     1.098681
# RSI                        41.845522
# candle                             G
# EMA_20                      1.097072
# upper_keltner               1.099466
# lower_keltner               1.094678
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09598
# high                         1.09608
# low                          1.09516
# close                         1.0953
# date             2023-08-11 16:30:00
# EMA_8                        1.09599
# EMA_50                      1.097822
# EMA_200                     1.098625
# RSI                        38.021485
# candle                             R
# EMA_20                      1.096809
# upper_keltner               1.099105
# lower_keltner               1.094513
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09531
# high                         1.09531
# low                          1.09454
# close                        1.09461
# date             2023-08-11 16:45:00
# EMA_8                       1.095683
# EMA_50                      1.097696
# EMA_200                     1.098588
# RSI                        35.488517
# candle                             R
# EMA_20                        1.0966
# upper_keltner               1.098839
# lower_keltner                1.09436
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09532
# high                         1.09532
# low                          1.09431
# close                        1.09445
# date             2023-08-11 17:30:00
# EMA_8                       1.095232
# EMA_50                      1.097376
# EMA_200                     1.098484
# RSI                         36.64306
# candle                             R
# EMA_20                      1.096147
# upper_keltner               1.098246
# lower_keltner               1.094048
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09317
# high                          1.0943
# low                          1.09293
# close                        1.09412
# date             2023-08-14 07:00:00
# EMA_8                       1.093502
# EMA_50                      1.094115
# EMA_200                     1.096567
# RSI                        52.047965
# candle                             G
# EMA_20                      1.093513
# upper_keltner               1.094863
# lower_keltner               1.092163
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09273
# high                         1.09376
# low                          1.09268
# close                        1.09354
# date             2023-08-15 09:30:00
# EMA_8                       1.092685
# EMA_50                      1.091722
# EMA_200                     1.093318
# RSI                        62.662496
# candle                             G
# EMA_20                      1.092183
# upper_keltner               1.093922
# lower_keltner               1.090443
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09353
# high                         1.09356
# low                          1.09229
# close                        1.09267
# date             2023-08-15 15:15:00
# EMA_8                       1.093318
# EMA_50                      1.092686
# EMA_200                      1.09329
# RSI                        49.197271
# candle                             R
# EMA_20                      1.093211
# upper_keltner               1.095833
# lower_keltner               1.090589
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09077
# high                         1.09229
# low                          1.09072
# close                         1.0917
# date             2023-08-16 13:30:00
# EMA_8                       1.091016
# EMA_50                      1.091453
# EMA_200                     1.092114
# RSI                        52.077155
# candle                             G
# EMA_20                      1.091337
# upper_keltner               1.093292
# lower_keltner               1.089383
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09083
# high                         1.09229
# low                          1.09063
# close                        1.09188
# date             2023-08-16 14:00:00
# EMA_8                       1.091176
# EMA_50                      1.091446
# EMA_200                     1.092099
# RSI                        53.025179
# candle                             G
# EMA_20                      1.091345
# upper_keltner               1.093575
# lower_keltner               1.089115
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09149
# high                         1.09157
# low                          1.09028
# close                        1.09053
# date             2023-08-16 14:30:00
# EMA_8                        1.09109
# EMA_50                      1.091413
# EMA_200                     1.092078
# RSI                        44.400636
# candle                             R
# EMA_20                      1.091282
# upper_keltner               1.093542
# lower_keltner               1.089021
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08827
# high                         1.08997
# low                           1.0882
# close                        1.08947
# date             2023-08-16 18:15:00
# EMA_8                       1.089033
# EMA_50                      1.090465
# EMA_200                     1.091714
# RSI                         45.06268
# candle                             G
# EMA_20                      1.089643
# upper_keltner               1.091658
# lower_keltner               1.087629
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0892
# high                         1.08932
# low                          1.08787
# close                        1.08803
# date             2023-08-16 18:45:00
# EMA_8                       1.088839
# EMA_50                      1.090321
# EMA_200                     1.091655
# RSI                        38.288683
# candle                             R
# EMA_20                      1.089451
# upper_keltner               1.091598
# lower_keltner               1.087305
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09092
# high                         1.09092
# low                          1.08972
# close                         1.0899
# date             2023-08-17 13:45:00
# EMA_8                       1.090298
# EMA_50                       1.08856
# EMA_200                     1.089701
# RSI                        58.263744
# candle                             R
# EMA_20                      1.089426
# upper_keltner               1.091626
# lower_keltner               1.087225
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08781
# high                         1.08796
# low                          1.08706
# close                        1.08715
# date             2023-08-18 06:45:00
# EMA_8                       1.087925
# EMA_50                      1.087983
# EMA_200                     1.088728
# RSI                        41.680169
# candle                             R
# EMA_20                      1.088109
# upper_keltner               1.089315
# lower_keltner               1.086902
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08753
# high                         1.08755
# low                           1.0866
# close                        1.08661
# date             2023-08-18 10:30:00
# EMA_8                       1.086992
# EMA_50                       1.08754
# EMA_200                     1.088482
# RSI                        42.220251
# candle                             R
# EMA_20                      1.087234
# upper_keltner               1.088636
# lower_keltner               1.085832
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0855
# high                         1.08683
# low                          1.08527
# close                        1.08666
# date             2023-08-18 13:00:00
# EMA_8                       1.086036
# EMA_50                      1.087038
# EMA_200                     1.088237
# RSI                        48.185204
# candle                             G
# EMA_20                      1.086448
# upper_keltner                1.08825
# lower_keltner               1.084645
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09014
# high                         1.09018
# low                          1.08931
# close                        1.08938
# date             2023-08-21 10:15:00
# EMA_8                       1.089405
# EMA_50                      1.088294
# EMA_200                     1.088026
# RSI                         59.42959
# candle                             R
# EMA_20                      1.088876
# upper_keltner               1.090254
# lower_keltner               1.087498
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0905
# high                         1.09148
# low                           1.0905
# close                         1.0914
# date             2023-08-22 06:00:00
# EMA_8                       1.091103
# EMA_50                      1.090332
# EMA_200                     1.089146
# RSI                        58.979579
# candle                             G
# EMA_20                      1.090906
# upper_keltner                1.09193
# lower_keltner               1.089883
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09254
# high                         1.09282
# low                          1.09177
# close                        1.09179
# date             2023-08-22 08:00:00
# EMA_8                       1.092074
# EMA_50                      1.090836
# EMA_200                     1.089385
# RSI                          56.4658
# candle                             R
# EMA_20                      1.091615
# upper_keltner               1.092923
# lower_keltner               1.090307
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08494
# high                         1.08504
# low                          1.08412
# close                        1.08419
# date             2023-08-24 11:45:00
# EMA_8                       1.085049
# EMA_50                      1.085749
# EMA_200                     1.085956
# RSI                        36.232355
# candle                             R
# EMA_20                       1.08543
# upper_keltner               1.086779
# lower_keltner               1.084081
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                            1.08
# high                          1.0808
# low                          1.07995
# close                        1.08078
# date             2023-08-25 13:45:00
# EMA_8                       1.080571
# EMA_50                      1.079802
# EMA_200                     1.082092
# RSI                        57.126216
# candle                             G
# EMA_20                      1.080152
# upper_keltner               1.081723
# lower_keltner               1.078581
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07712
# high                         1.07841
# low                          1.07679
# close                        1.07781
# date             2023-08-25 15:00:00
# EMA_8                        1.07901
# EMA_50                      1.079627
# EMA_200                      1.08194
# RSI                        43.202605
# candle                             G
# EMA_20                       1.07958
# upper_keltner               1.082976
# lower_keltner               1.076184
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07781
# high                         1.07872
# low                          1.07681
# close                        1.07853
# date             2023-08-25 15:15:00
# EMA_8                       1.078904
# EMA_50                      1.079584
# EMA_200                     1.081906
# RSI                        46.188183
# candle                             G
# EMA_20                       1.07948
# upper_keltner               1.082966
# lower_keltner               1.075994
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08067
# high                          1.0807
# low                          1.07996
# close                        1.08001
# date             2023-08-28 08:45:00
# EMA_8                       1.080696
# EMA_50                      1.080599
# EMA_200                     1.081206
# RSI                        43.539756
# candle                             R
# EMA_20                       1.08086
# upper_keltner               1.082047
# lower_keltner               1.079674
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08137
# high                         1.08249
# low                          1.08132
# close                        1.08235
# date             2023-08-29 07:15:00
# EMA_8                       1.081864
# EMA_50                      1.082181
# EMA_200                     1.081565
# RSI                        50.856737
# candle                             G
# EMA_20                      1.082234
# upper_keltner                1.08339
# lower_keltner               1.081079
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08284
# high                         1.08293
# low                          1.08159
# close                        1.08198
# date             2023-08-29 07:45:00
# EMA_8                       1.082057
# EMA_50                      1.082197
# EMA_200                     1.081579
# RSI                        47.744815
# candle                             R
# EMA_20                      1.082261
# upper_keltner                1.08363
# lower_keltner               1.080892
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08199
# high                         1.08223
# low                          1.08117
# close                        1.08128
# date             2023-08-29 08:00:00
# EMA_8                       1.081884
# EMA_50                      1.082161
# EMA_200                     1.081574
# RSI                        43.007074
# candle                             R
# EMA_20                      1.082168
# upper_keltner               1.083639
# lower_keltner               1.080697
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07838
# high                         1.07972
# low                          1.07832
# close                        1.07957
# date             2023-08-29 13:30:00
# EMA_8                       1.079347
# EMA_50                      1.080984
# EMA_200                     1.081293
# RSI                        42.406933
# candle                             G
# EMA_20                      1.080109
# upper_keltner                1.08207
# lower_keltner               1.078149
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07956
# high                          1.0806
# low                          1.07954
# close                        1.08035
# date             2023-08-29 13:45:00
# EMA_8                        1.07957
# EMA_50                      1.080959
# EMA_200                     1.081282
# RSI                        47.364189
# candle                             G
# EMA_20                      1.080132
# upper_keltner               1.082136
# lower_keltner               1.078129
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08643
# high                         1.08645
# low                          1.08548
# close                        1.08574
# date             2023-08-30 08:00:00
# EMA_8                       1.086382
# EMA_50                      1.086403
# EMA_200                     1.084134
# RSI                        43.019223
# candle                             R
# EMA_20                      1.086542
# upper_keltner               1.087942
# lower_keltner               1.085143
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.09275
# high                         1.09276
# low                          1.09188
# close                          1.092
# date             2023-08-30 17:45:00
# EMA_8                       1.092563
# EMA_50                      1.090513
# EMA_200                     1.086382
# RSI                        56.512843
# candle                             R
# EMA_20                      1.092199
# upper_keltner               1.093866
# lower_keltner               1.090531
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08678
# high                           1.088
# low                          1.08649
# close                        1.08789
# date             2023-08-31 12:00:00
# EMA_8                       1.087168
# EMA_50                      1.089473
# EMA_200                     1.088533
# RSI                        41.391905
# candle                             G
# EMA_20                      1.087921
# upper_keltner               1.089715
# lower_keltner               1.086127
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08414
# high                         1.08548
# low                          1.08398
# close                        1.08544
# date             2023-08-31 14:45:00
# EMA_8                       1.085353
# EMA_50                      1.088118
# EMA_200                     1.088229
# RSI                        38.701916
# candle                             G
# EMA_20                      1.086314
# upper_keltner               1.088969
# lower_keltner                1.08366
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08484
# high                         1.08489
# low                          1.08403
# close                         1.0841
# date             2023-09-01 11:30:00
# EMA_8                       1.084564
# EMA_50                      1.084718
# EMA_200                     1.086093
# RSI                        45.284502
# candle                             R
# EMA_20                       1.08467
# upper_keltner               1.085969
# lower_keltner                1.08337
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0841
# high                         1.08432
# low                          1.08327
# close                        1.08328
# date             2023-09-01 11:45:00
# EMA_8                       1.084279
# EMA_50                      1.084662
# EMA_200                     1.086065
# RSI                        39.857682
# candle                             R
# EMA_20                      1.084537
# upper_keltner               1.085943
# lower_keltner               1.083131
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08328
# high                         1.08446
# low                          1.08321
# close                        1.08428
# date             2023-09-01 12:00:00
# EMA_8                       1.084279
# EMA_50                      1.084647
# EMA_200                     1.086048
# RSI                        47.858826
# candle                             G
# EMA_20                      1.084513
# upper_keltner                1.08606
# lower_keltner               1.082966
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.08034
# high                         1.08035
# low                          1.07948
# close                        1.07954
# date             2023-09-04 13:45:00
# EMA_8                       1.079969
# EMA_50                      1.079552
# EMA_200                     1.081612
# RSI                        49.377669
# candle                             R
# EMA_20                      1.079899
# upper_keltner               1.080975
# lower_keltner               1.078822
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07308
# high                         1.07468
# low                          1.07247
# close                        1.07436
# date             2023-09-05 12:45:00
# EMA_8                       1.073573
# EMA_50                      1.075974
# EMA_200                     1.079042
# RSI                        42.722098
# candle                             G
# EMA_20                      1.074331
# upper_keltner                1.07652
# lower_keltner               1.072141
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07333
# high                         1.07466
# low                          1.07329
# close                        1.07451
# date             2023-09-05 13:15:00
# EMA_8                       1.073741
# EMA_50                      1.075817
# EMA_200                     1.078945
# RSI                           45.239
# candle                             G
# EMA_20                      1.074262
# upper_keltner               1.076647
# lower_keltner               1.071877
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07311
# high                          1.0739
# low                          1.07301
# close                        1.07377
# date             2023-09-06 06:15:00
# EMA_8                       1.073452
# EMA_50                       1.07295
# EMA_200                     1.075868
# RSI                        57.778043
# candle                             G
# EMA_20                      1.073125
# upper_keltner               1.074273
# lower_keltner               1.071977
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07379
# high                         1.07381
# low                          1.07288
# close                         1.0731
# date             2023-09-06 06:30:00
# EMA_8                       1.073374
# EMA_50                      1.072956
# EMA_200                     1.075842
# RSI                         51.53965
# candle                             R
# EMA_20                      1.073122
# upper_keltner               1.074365
# lower_keltner                1.07188
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.06952
# high                         1.07082
# low                          1.06933
# close                        1.07076
# date             2023-09-07 14:30:00
# EMA_8                       1.069895
# EMA_50                      1.070963
# EMA_200                     1.072907
# RSI                        49.788186
# candle                             G
# EMA_20                      1.070226
# upper_keltner               1.072145
# lower_keltner               1.068307
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07113
# high                         1.07113
# low                          1.07026
# close                        1.07048
# date             2023-09-08 09:00:00
# EMA_8                       1.071149
# EMA_50                      1.071127
# EMA_200                     1.071775
# RSI                        43.905252
# candle                             R
# EMA_20                      1.071338
# upper_keltner               1.072632
# lower_keltner               1.070045
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                          1.0725
# high                         1.07323
# low                          1.07246
# close                        1.07322
# date             2023-09-11 06:30:00
# EMA_8                       1.073016
# EMA_50                      1.071969
# EMA_200                     1.071596
# RSI                        59.854858
# candle                             G
# EMA_20                      1.072679
# upper_keltner               1.073923
# lower_keltner               1.071435
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07423
# high                         1.07558
# low                          1.07422
# close                        1.07549
# date             2023-09-11 16:00:00
# EMA_8                       1.074547
# EMA_50                      1.073196
# EMA_200                     1.072135
# RSI                         63.97878
# candle                             G
# EMA_20                       1.07395
# upper_keltner               1.075768
# lower_keltner               1.072131
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07196
# high                         1.07215
# low                          1.07129
# close                        1.07131
# date             2023-09-12 10:30:00
# EMA_8                       1.071946
# EMA_50                      1.073177
# EMA_200                      1.07296
# RSI                         35.67762
# candle                             R
# EMA_20                      1.072405
# upper_keltner               1.073729
# lower_keltner                1.07108
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07157
# high                         1.07158
# low                          1.07054
# close                        1.07071
# date             2023-09-12 12:45:00
# EMA_8                       1.071299
# EMA_50                      1.072616
# EMA_200                     1.072814
# RSI                        36.793946
# candle                             R
# EMA_20                      1.071744
# upper_keltner               1.073349
# lower_keltner                1.07014
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07201
# high                         1.07297
# low                            1.072
# close                        1.07294
# date             2023-09-12 15:15:00
# EMA_8                       1.071844
# EMA_50                      1.072291
# EMA_200                     1.072697
# RSI                         55.93754
# candle                             G
# EMA_20                       1.07172
# upper_keltner               1.073335
# lower_keltner               1.070104
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07252
# high                         1.07343
# low                          1.07252
# close                        1.07338
# date             2023-09-12 16:00:00
# EMA_8                       1.072384
# EMA_50                      1.072349
# EMA_200                     1.072701
# RSI                        58.083799
# candle                             G
# EMA_20                      1.072004
# upper_keltner               1.073566
# lower_keltner               1.070443
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07322
# high                         1.07322
# low                          1.07231
# close                        1.07246
# date             2023-09-12 16:30:00
# EMA_8                       1.072549
# EMA_50                      1.072387
# EMA_200                     1.072704
# RSI                        51.275027
# candle                             R
# EMA_20                      1.072154
# upper_keltner               1.073725
# lower_keltner               1.070583
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07353
# high                         1.07439
# low                          1.07347
# close                        1.07429
# date             2023-09-13 07:15:00
# EMA_8                       1.074099
# EMA_50                      1.074412
# EMA_200                     1.073546
# RSI                        48.332744
# candle                             G
# EMA_20                      1.074428
# upper_keltner               1.075686
# lower_keltner               1.073171
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.07308
# high                         1.07423
# low                          1.07301
# close                        1.07398
# date             2023-09-13 14:30:00
# EMA_8                       1.073753
# EMA_50                      1.073921
# EMA_200                     1.073575
# RSI                        50.523258
# candle                             G
# EMA_20                      1.073768
# upper_keltner               1.076745
# lower_keltner               1.070791
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.06635
# high                         1.06725
# low                          1.06629
# close                        1.06719
# date             2023-09-14 15:00:00
# EMA_8                       1.067152
# EMA_50                      1.071176
# EMA_200                     1.072878
# RSI                        36.025714
# candle                             G
# EMA_20                      1.068972
# upper_keltner               1.072248
# lower_keltner               1.065697
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
# DF:  open                         1.06673
# high                         1.06681
# low                            1.066
# close                        1.06601
# date             2023-09-15 10:15:00
# EMA_8                       1.066345
# EMA_50                      1.065692
# EMA_200                     1.068606
# RSI                        52.772589
# candle                             R
# EMA_20                      1.066054
# upper_keltner               1.067314
# lower_keltner               1.064795
# pos                              1.0
# candle_size                      1.0
# prev_candle                     True
# Name: 499, dtype: object
